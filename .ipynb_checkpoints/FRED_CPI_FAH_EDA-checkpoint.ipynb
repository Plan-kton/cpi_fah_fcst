# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV file
df = pd.read_csv('fetch_fred_data.csv')
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df = df[df['date'] >= '2004-01-01']
df = df.reset_index().set_index('date').drop(columns = 'index')

df
# Out:
#                  GDP  Real Consumer Exp  Business Inv  Govt Expenditure  \
# date
# 2004-01-01  15248.68                NaN       288.018          3947.702
# 2004-02-01  15248.68                NaN       288.018          3947.702
# 2004-03-01  15248.68                NaN       288.018          3947.702
# 2004-04-01  15366.85                NaN       345.442          3982.852
# 2004-05-01  15366.85                NaN       345.442          3982.852
# ...              ...                ...           ...               ...
# 2024-12-01       NaN            16357.7           NaN               NaN
# 2025-01-01       NaN            16257.6           NaN               NaN
# 2025-02-01       NaN            16274.2           NaN               NaN
# 2025-03-01       NaN                NaN           NaN               NaN
# 2025-04-01       NaN                NaN           NaN               NaN
#
#             Net Exports   Imports   Exports      CPI  Real Disposable Income  \
# date
# 2004-01-01     -621.175  2044.535  1339.286  186.300                 11051.2
# 2004-02-01     -621.175  2044.535  1339.286  186.700                 11071.0
# 2004-03-01     -621.175  2044.535  1339.286  187.100                 11115.6
# 2004-04-01     -670.333  2044.535  1367.358  187.400                 11153.3
# 2004-05-01     -670.333  2044.535  1367.358  188.200                 11208.9
# ...                 ...       ...       ...      ...                     ...
# 2024-12-01          NaN       NaN       NaN  317.603                 17605.8
# 2025-01-01          NaN       NaN       NaN  319.086                 17661.4
# 2025-02-01          NaN       NaN       NaN  319.775                 17756.2
# 2025-03-01          NaN       NaN       NaN  319.615                     NaN
# 2025-04-01          NaN       NaN       NaN      NaN                     NaN
#
#             Unemployment Rate  ...  Retail Wages  US Population  \
# date                           ...
# 2004-01-01                5.7  ...           NaN       292046.0
# 2004-02-01                5.6  ...           NaN       292230.0
# 2004-03-01                5.8  ...           NaN       292434.0
# 2004-04-01                5.6  ...           NaN       292651.0
# 2004-05-01                5.6  ...           NaN       292872.0
# ...                       ...  ...           ...            ...
# 2024-12-01                4.1  ...         24.86       341320.0
# 2025-01-01                4.0  ...         24.97       341454.0
# 2025-02-01                4.1  ...         25.01       341588.0
# 2025-03-01                4.2  ...         25.18            NaN
# 2025-04-01                NaN  ...           NaN            NaN
#
#             CPI (Food at Home)  CPI (Food away from Home)  Grocery Sales  \
# date
# 2004-01-01             183.300                    184.900        36402.0
# 2004-02-01             183.700                    185.500        35890.0
# 2004-03-01             184.100                    185.800        36365.0
# 2004-04-01             184.300                    186.200        36312.0
# 2004-05-01             186.600                    186.700        36528.0
# ...                        ...                        ...            ...
# 2024-12-01             309.754                    374.644        75998.0
# 2025-01-01             311.178                    375.532        76071.0
# 2025-02-01             311.203                    376.991        76383.0
# 2025-03-01             312.713                    378.363            NaN
# 2025-04-01                 NaN                        NaN            NaN
#
#             Restaurant Sales  Grocery Units  Restaurant Units  \
# date
# 2004-01-01           24839.0     198.592471        134.337480
# 2004-02-01           24952.0     195.372891        134.512129
# 2004-03-01           27054.0     197.528517        145.608181
# 2004-04-01           26738.0     197.026587        143.598281
# 2004-05-01           27839.0     195.755627        149.110873
# ...                      ...            ...               ...
# 2024-12-01           86965.0     245.349535        232.127033
# 2025-01-01           80656.0     244.461369        214.777968
# 2025-02-01               NaN     245.444292               NaN
# 2025-03-01               NaN            NaN               NaN
# 2025-04-01               NaN            NaN               NaN
#
#             Grocery Units per Capita  Restaurant Units per Capita
# date
# 2004-01-01                  0.000680                     0.000460
# 2004-02-01                  0.000669                     0.000460
# 2004-03-01                  0.000675                     0.000498
# 2004-04-01                  0.000673                     0.000491
# 2004-05-01                  0.000668                     0.000509
# ...                              ...                          ...
# 2024-12-01                  0.000719                     0.000680
# 2025-01-01                  0.000716                     0.000629
# 2025-02-01                  0.000719                          NaN
# 2025-03-01                       NaN                          NaN
# 2025-04-01                       NaN                          NaN
#
# [256 rows x 32 columns]

# %%
df_cpi = df[["Grocery Sales", "CPI (Food at Home)", "Restaurant Sales", "Oil Prices", "PPI Farm Products", "PPI Food Manufacture",
            "PPI Grocery", "Retail Wages"]]

df_cpi = df_cpi.rename(columns={
        "Grocery Sales": 'grocery_sales',  
        "CPI (Food at Home)": 'cpi_fah', 
        "Restaurant Sales": 'restaurant_sales',
        "Oil Prices": 'oil_prices',        
        "PPI Farm Products": 'ppi_farm_products',
        "PPI Food Manufacture": 'ppi_food_mfg',
        "PPI Grocery": 'ppi_grocery',
        "Retail Wages": 'wages_retail'
    }
)

df_cpi['grocery_units'] = df_cpi['grocery_sales']/df_cpi['cpi_fah']

# %%
df_cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 256 entries, 2004-01-01 to 2025-04-01
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   grocery_sales      254 non-null    float64
#  1   cpi_fah            255 non-null    float64
#  2   restaurant_sales   253 non-null    float64
#  3   oil_prices         256 non-null    float64
#  4   ppi_farm_products  255 non-null    float64
#  5   ppi_food_mfg       255 non-null    float64
#  6   ppi_grocery        255 non-null    float64
#  7   wages_retail       229 non-null    float64
#  8   grocery_units      254 non-null    float64
# dtypes: float64(9)
# memory usage: 20.0 KB

# %% [markdown]
# ### Describe the Data ###

# %%
df_cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 256 entries, 2004-01-01 to 2025-04-01
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   grocery_sales      254 non-null    float64
#  1   cpi_fah            255 non-null    float64
#  2   restaurant_sales   253 non-null    float64
#  3   oil_prices         256 non-null    float64
#  4   ppi_farm_products  255 non-null    float64
#  5   ppi_food_mfg       255 non-null    float64
#  6   ppi_grocery        255 non-null    float64
#  7   wages_retail       229 non-null    float64
#  8   grocery_units      254 non-null    float64
# dtypes: float64(9)
# memory usage: 20.0 KB

# %%
print(df_cpi.index)
# Out:
# DatetimeIndex(['2004-01-01', '2004-02-01', '2004-03-01', '2004-04-01',
#                '2004-05-01', '2004-06-01', '2004-07-01', '2004-08-01',
#                '2004-09-01', '2004-10-01',
#                ...
#                '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01',
#                '2024-11-01', '2024-12-01', '2025-01-01', '2025-02-01',
#                '2025-03-01', '2025-04-01'],
#               dtype='datetime64[ns]', name='date', length=256, freq=None)

# %%
df_cpi.describe().T
# Out:
#                    count          mean           std           min  \
# grocery_sales      254.0  52310.665354  11692.896869  35890.000000
# cpi_fah            255.0    236.844737     33.509299    183.300000
# restaurant_sales   253.0  46515.150198  17025.423565  24839.000000
# oil_prices         256.0     70.377955     21.710763     16.547619
# ppi_farm_products  255.0    172.047918     37.024551    109.800000
# ppi_food_mfg       255.0    196.010251     33.242081    139.300000
# ppi_grocery        255.0    184.356408     43.898026    121.000000
# wages_retail       229.0     18.438515      3.119366     15.080000
# grocery_units      254.0    218.937105     20.543098    192.258730
#
#                             25%           50%           75%           max
# grocery_sales      42709.000000  50438.000000  58105.250000  76383.000000
# cpi_fah              215.212500    237.824000    243.241000    312.713000
# restaurant_sales   32930.000000  41469.000000  55069.000000  89624.000000
# oil_prices            53.205119     70.175100     85.929617    133.880000
# ppi_farm_products    146.050000    166.200000    196.100000    263.817000
# ppi_food_mfg         171.300000    198.000000    204.800000    266.852000
# ppi_grocery          149.950000    177.700000    206.950000    293.162000
# wages_retail          15.650000     17.650000     20.950000     25.180000
# grocery_units        202.114923    209.788522    239.925283    302.705527

# %% [markdown]
# ### Missing Values, Duplicates, and Outliers ###

# %%
# Count total missing values per column
missing_counts = df_cpi.isna().sum()

# Show only columns with missing values
missing_counts = missing_counts[missing_counts > 0]

missing_counts
# Out:
# grocery_sales         2
# cpi_fah               1
# restaurant_sales      3
# ppi_farm_products     1
# ppi_food_mfg          1
# ppi_grocery           1
# wages_retail         27
# grocery_units         2
# dtype: int64

# %%
# Check for duplicates
df_cpi.duplicated().sum()
# Out:
# 0

# %%
# Identify outliers using IQR
cols = df_cpi.columns.tolist()

Q1 = df_cpi[cols].quantile(0.25)
Q3 = df_cpi[cols].quantile(0.75)

IQR = Q3 - Q1

lower_whisker = Q1 - 1.5 * IQR
upper_whisker = Q3 + 1.5 * IQR

IQR_df_cpi = pd.DataFrame(
    {'Column': Q1.index,                        # Column names
    'Q1 (25th percentile)': Q1.values,          # Q1 values
    'Q3 (75th percentile)': Q3.values,          # Q3 values
    'IQR': IQR.values,                          # Interquartile range
    'Lower Whisker': lower_whisker.values,      # Lower whisker
    'Upper Whisker': upper_whisker.values})      # Upper whisker

#This provides the percent of values above or below the whiskers
((df_cpi[cols] < lower_whisker) | (df_cpi[cols] > upper_whisker)).sum() / len(df_cpi) * 100
# Out:
# grocery_sales         0.000000
# cpi_fah              13.671875
# restaurant_sales      0.781250
# oil_prices            0.000000
# ppi_farm_products     0.000000
# ppi_food_mfg          8.203125
# ppi_grocery           0.390625
# wages_retail          0.000000
# grocery_units         0.390625
# dtype: float64

# %% [markdown]
# ### Visualizations ###

# %%
# Select the variables to plot (excluding 'date')
var_list = df_cpi.columns.tolist()

# Create a grid of subplots (2 columns × enough rows for all variables)
num_vars = len(var_list)
rows = (num_vars // 2) + (num_vars % 2)  # Ensures enough rows for all variables

fig, axes = plt.subplots(nrows=rows, ncols=2, figsize=(15, 5 * rows))  # Dynamically sized

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and plot
for i, col in enumerate(var_list):
    ax = axes[i]  # Select the subplot
    ax.plot(df_cpi.index, df_cpi[col], label=col, linewidth=2)
    
    # Customize the subplot
    ax.set_title(col, fontsize=12)
    ax.set_xlabel("Date", fontsize=10)
    ax.set_ylabel("Value", fontsize=10)
    ax.grid(True)
    ax.legend()

# Adjust layout for readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Select independent variables (excluding index)
var_list = df_cpi.columns.tolist()  # Since 'date' is index, it's not included

# Create a grid of subplots (2 columns × enough rows for all variables)
num_vars = len(var_list)
rows = (num_vars // 2) + (num_vars % 2)  # Ensures enough rows for all variables

fig, axes = plt.subplots(nrows=rows, ncols=2, figsize=(15, 5 * rows))  # Dynamically sized

# Flatten axes array for easier iteration
axes = axes.flatten()

# Loop through each variable and create scatter plots
for i, col in enumerate(var_list):
    ax = axes[i]
    ax.scatter(df_cpi[col], df_cpi['cpi_fah'], color='red', alpha=0.6)
    ax.set_xlabel(col, fontsize=10)
    ax.set_ylabel('Food Inflation', fontsize=10)
    ax.set_title(f'Scatter Plot: {col} vs Food Inflation')

# Hide empty subplots if `var_list` has an odd number of elements
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and show all plots
plt.tight_layout()
plt.show()

# %%
# Compute the correlation matrix
df_cpi_corr = df_cpi.select_dtypes(include=['number']).corr()

plt.figure(figsize=(14, 6))
sns.heatmap(df_cpi_corr, annot=True, cbar=False, cmap="coolwarm")
plt.show()

# %%
df_cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 256 entries, 2004-01-01 to 2025-04-01
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   grocery_sales      254 non-null    float64
#  1   cpi_fah            255 non-null    float64
#  2   restaurant_sales   253 non-null    float64
#  3   oil_prices         256 non-null    float64
#  4   ppi_farm_products  255 non-null    float64
#  5   ppi_food_mfg       255 non-null    float64
#  6   ppi_grocery        255 non-null    float64
#  7   wages_retail       229 non-null    float64
#  8   grocery_units      254 non-null    float64
# dtypes: float64(9)
# memory usage: 20.0 KB

# %% [markdown]
# ### Feature Creation ###

# %%
#feature creation

# Create first difference variables (applies to all numeric columns)
df_cpi_diff = df_cpi.diff().add_suffix('_diff')
df_cpi_diff = df_cpi_diff.bfill()

# Create YOY variables (applies to all numeric columns)
df_cpi_yoy = df_cpi.pct_change(periods=12, fill_method=None).add_suffix('_yoy') * 100  # Converts to percentage

# Create dummy1 for dates between 2/29/2020 and 4/30/2020. A boolean consition with a .astype(int) will return a 1 for True and 0 for false
df_cpi['covid1'] = ((df_cpi.index >= '2020-02-01') & (df_cpi.index <= '2020-04-01')).astype(int)

# Create dummy2 for dates between 5/31/2020 and 10/31/2020
df_cpi['covid2'] = ((df_cpi.index >= '2020-05-01') & (df_cpi.index <= '2020-10-01')).astype(int)

# %%
df_cpi = pd.concat([df_cpi, df_cpi_diff, df_cpi_yoy], axis=1)

# %% [markdown]
# ### Lag Variable Analysis ###

# %%
# 1) create lagged variables
lag_vars = ['cpi_fah_yoy', 'oil_prices_yoy', 'ppi_farm_products_yoy', 'ppi_food_mfg_yoy', 'ppi_grocery_yoy', 'wages_retail_yoy']

lags = range(1, 13)

lagged_cols = {}

for lag_var in lag_vars:
    for lag in lags:
        col_name = f'{lag_var}_lag{lag}'
        lagged_cols[col_name] = df_cpi[lag_var].shift(lag)

# Add all lagged columns at once using concat
df_cpi = pd.concat([df_cpi, pd.DataFrame(lagged_cols, index=df_cpi.index)], axis=1)

# %%
for col in df_cpi.columns:
    print(col)
# Out:
# grocery_sales
# cpi_fah
# restaurant_sales
# oil_prices
# ppi_farm_products
# ppi_food_mfg
# ppi_grocery
# wages_retail
# grocery_units
# covid1
# covid2
# grocery_sales_diff
# cpi_fah_diff
# restaurant_sales_diff
# oil_prices_diff
# ppi_farm_products_diff
# ppi_food_mfg_diff
# ppi_grocery_diff
# wages_retail_diff
# grocery_units_diff
# grocery_sales_yoy
# cpi_fah_yoy
# restaurant_sales_yoy
# oil_prices_yoy
# ppi_farm_products_yoy
# ppi_food_mfg_yoy
# ppi_grocery_yoy
# wages_retail_yoy
# grocery_units_yoy
# cpi_fah_yoy_lag1
# cpi_fah_yoy_lag2
# cpi_fah_yoy_lag3
# cpi_fah_yoy_lag4
# cpi_fah_yoy_lag5
# cpi_fah_yoy_lag6
# cpi_fah_yoy_lag7
# cpi_fah_yoy_lag8
# cpi_fah_yoy_lag9
# cpi_fah_yoy_lag10
# cpi_fah_yoy_lag11
# cpi_fah_yoy_lag12
# oil_prices_yoy_lag1
# oil_prices_yoy_lag2
# oil_prices_yoy_lag3
# oil_prices_yoy_lag4
# oil_prices_yoy_lag5
# oil_prices_yoy_lag6
# oil_prices_yoy_lag7
# oil_prices_yoy_lag8
# oil_prices_yoy_lag9
# oil_prices_yoy_lag10
# oil_prices_yoy_lag11
# oil_prices_yoy_lag12
# ppi_farm_products_yoy_lag1
# ppi_farm_products_yoy_lag2
# ppi_farm_products_yoy_lag3
# ppi_farm_products_yoy_lag4
# ppi_farm_products_yoy_lag5
# ppi_farm_products_yoy_lag6
# ppi_farm_products_yoy_lag7
# ppi_farm_products_yoy_lag8
# ppi_farm_products_yoy_lag9
# ppi_farm_products_yoy_lag10
# ppi_farm_products_yoy_lag11
# ppi_farm_products_yoy_lag12
# ppi_food_mfg_yoy_lag1
# ppi_food_mfg_yoy_lag2
# ppi_food_mfg_yoy_lag3
# ppi_food_mfg_yoy_lag4
# ppi_food_mfg_yoy_lag5
# ppi_food_mfg_yoy_lag6
# ppi_food_mfg_yoy_lag7
# ppi_food_mfg_yoy_lag8
# ppi_food_mfg_yoy_lag9
# ppi_food_mfg_yoy_lag10
# ppi_food_mfg_yoy_lag11
# ppi_food_mfg_yoy_lag12
# ppi_grocery_yoy_lag1
# ppi_grocery_yoy_lag2
# ppi_grocery_yoy_lag3
# ppi_grocery_yoy_lag4
# ppi_grocery_yoy_lag5
# ppi_grocery_yoy_lag6
# ppi_grocery_yoy_lag7
# ppi_grocery_yoy_lag8
# ppi_grocery_yoy_lag9
# ppi_grocery_yoy_lag10
# ppi_grocery_yoy_lag11
# ppi_grocery_yoy_lag12
# wages_retail_yoy_lag1
# wages_retail_yoy_lag2
# wages_retail_yoy_lag3
# wages_retail_yoy_lag4
# wages_retail_yoy_lag5
# wages_retail_yoy_lag6
# wages_retail_yoy_lag7
# wages_retail_yoy_lag8
# wages_retail_yoy_lag9
# wages_retail_yoy_lag10
# wages_retail_yoy_lag11
# wages_retail_yoy_lag12

# %%
lags = range(1, 13)

# 1) define vars
ppi_vars = ['oil_prices_yoy', 'ppi_farm_products_yoy', 'ppi_food_mfg_yoy', 'ppi_grocery_yoy', 'wages_retail_yoy']
target_var = 'cpi_fah_yoy'

# Dictionary to store results
correlation_results = {}

for ppi_var in ppi_vars:
    lag_cols = []
    for lag in lags:
        lag_col = f'{ppi_var}_lag{lag}'
        lag_cols.append(lag_col)

    # Compute correlation matrix with lagged variables
    corrs = df_cpi[[target_var] + lag_cols].corr()
    corr_values = corrs.loc[target_var, lag_cols]
    correlation_results[ppi_var] = corr_values.values

# Convert to DataFrame
corr_df_cpi_ppi = pd.DataFrame(correlation_results, index=[f'lag{lag}' for lag in lags])

# 2) Plot the results
plt.figure(figsize=(10, 6))

for i, column in enumerate(corr_df_cpi_ppi.columns):
    plt.plot(lags, corr_df_cpi_ppi.iloc[:, i], marker='o', linewidth=2,
             label=column.replace('_yoy', '').replace('_', ' ').title())

plt.title('Correlation of CPI Food at Home with Lagged PPI Variables')
plt.xlabel('Lag (months)')
plt.ylabel('Correlation Coefficient')
plt.xticks(lags)
plt.ylim(-0.25, 1)
plt.legend(title="Independent Variables", loc='lower left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_cpi.to_csv('cpi_fah_eda_dataset.csv', index = True)
